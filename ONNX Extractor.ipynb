# %% [markdown]
# This notebook uses ONNX Python API to create an ONNX extractor. It extracts the layer based on the specified model indices. (The ONNX model is visualized through the Netron app). The pickle dataset is created based on the ONNX patterns extracted, which contains metadata for the specific patterns.

# %%
# Extracting layers using ONNX extractor API

# %%
#This code will load the ONNX model from the specified path, extract the graph object from the model and get the names of all the nodes (layers)
#in the graph
import onnx

model_path = "ONNX_models/resnet18-v1-7.onnx"

# Load the model
model = onnx.load(model_path)

# Get the graph object from the model
graph = model.graph

# Get the names of all the nodes in the graph
node_names = [node.name for node in graph.node]

# Print the node names
print(node_names)
# Out:
# ['resnetv15_conv0_fwd', 'resnetv15_batchnorm0_fwd', 'resnetv15_relu0_fwd', 'resnetv15_pool0_fwd', 'resnetv15_stage1_conv0_fwd', 'resnetv15_stage1_batchnorm0_fwd', 'resnetv15_stage1_relu0_fwd', 'resnetv15_stage1_conv1_fwd', 'resnetv15_stage1_batchnorm1_fwd', 'resnetv15_stage1__plus0', 'resnetv15_stage1_activation0', 'resnetv15_stage1_conv2_fwd', 'resnetv15_stage1_batchnorm2_fwd', 'resnetv15_stage1_relu1_fwd', 'resnetv15_stage1_conv3_fwd', 'resnetv15_stage1_batchnorm3_fwd', 'resnetv15_stage1__plus1', 'resnetv15_stage1_activation1', 'resnetv15_stage2_conv2_fwd', 'resnetv15_stage2_batchnorm2_fwd', 'resnetv15_stage2_conv0_fwd', 'resnetv15_stage2_batchnorm0_fwd', 'resnetv15_stage2_relu0_fwd', 'resnetv15_stage2_conv1_fwd', 'resnetv15_stage2_batchnorm1_fwd', 'resnetv15_stage2__plus0', 'resnetv15_stage2_activation0', 'resnetv15_stage2_conv3_fwd', 'resnetv15_stage2_batchnorm3_fwd', 'resnetv15_stage2_relu1_fwd', 'resnetv15_stage2_conv4_fwd', 'resnetv15_stage2_batchnorm4_fwd', 'resnetv15_stage2__plus1', 'resnetv15_stage2_activation1', 'resnetv15_stage3_conv2_fwd', 'resnetv15_stage3_batchnorm2_fwd', 'resnetv15_stage3_conv0_fwd', 'resnetv15_stage3_batchnorm0_fwd', 'resnetv15_stage3_relu0_fwd', 'resnetv15_stage3_conv1_fwd', 'resnetv15_stage3_batchnorm1_fwd', 'resnetv15_stage3__plus0', 'resnetv15_stage3_activation0', 'resnetv15_stage3_conv3_fwd', 'resnetv15_stage3_batchnorm3_fwd', 'resnetv15_stage3_relu1_fwd', 'resnetv15_stage3_conv4_fwd', 'resnetv15_stage3_batchnorm4_fwd', 'resnetv15_stage3__plus1', 'resnetv15_stage3_activation1', 'resnetv15_stage4_conv2_fwd', 'resnetv15_stage4_batchnorm2_fwd', 'resnetv15_stage4_conv0_fwd', 'resnetv15_stage4_batchnorm0_fwd', 'resnetv15_stage4_relu0_fwd', 'resnetv15_stage4_conv1_fwd', 'resnetv15_stage4_batchnorm1_fwd', 'resnetv15_stage4__plus0', 'resnetv15_stage4_activation0', 'resnetv15_stage4_conv3_fwd', 'resnetv15_stage4_batchnorm3_fwd', 'resnetv15_stage4_relu1_fwd', 'resnetv15_stage4_conv4_fwd', 'resnetv15_stage4_batchnorm4_fwd', 'resnetv15_stage4__plus1', 'resnetv15_stage4_activation1', 'resnetv15_pool1_fwd', 'flatten_170', 'resnetv15_dense0_fwd']

# %%
import onnx
from onnx import utils
from onnx.numpy_helper import to_array
import numpy as np


def extract_range_layers(model_path, output_path, first_layer_index, last_layer_index):
    model = onnx.load(model_path)
    graph = model.graph
    nodes = graph.node[first_layer_index:last_layer_index+1]
    output_graph = onnx.GraphProto()
    output_graph.node.extend(nodes)
    output_model = onnx.helper.make_model(output_graph, producer_name='onnx-extractor')
    onnx.save(output_model, output_path)

# %%
import onnx

def model_indices(model_path):
    model = onnx.load(model_path)
    graph_def = model.graph

    for i, node in enumerate(graph_def.node):
        print(f"Node {i}: {node.name}")

model_indices("ONNX_models/resnet18-v1-7.onnx")
# Out:
# Node 0: resnetv15_conv0_fwd
# Node 1: resnetv15_batchnorm0_fwd
# Node 2: resnetv15_relu0_fwd
# Node 3: resnetv15_pool0_fwd
# Node 4: resnetv15_stage1_conv0_fwd
# Node 5: resnetv15_stage1_batchnorm0_fwd
# Node 6: resnetv15_stage1_relu0_fwd
# Node 7: resnetv15_stage1_conv1_fwd
# Node 8: resnetv15_stage1_batchnorm1_fwd
# Node 9: resnetv15_stage1__plus0
# Node 10: resnetv15_stage1_activation0
# Node 11: resnetv15_stage1_conv2_fwd
# Node 12: resnetv15_stage1_batchnorm2_fwd
# Node 13: resnetv15_stage1_relu1_fwd
# Node 14: resnetv15_stage1_conv3_fwd
# Node 15: resnetv15_stage1_batchnorm3_fwd
# Node 16: resnetv15_stage1__plus1
# Node 17: resnetv15_stage1_activation1
# Node 18: resnetv15_stage2_conv2_fwd
# Node 19: resnetv15_stage2_batchnorm2_fwd
# Node 20: resnetv15_stage2_conv0_fwd
# Node 21: resnetv15_stage2_batchnorm0_fwd
# Node 22: resnetv15_stage2_relu0_fwd
# Node 23: resnetv15_stage2_conv1_fwd
# Node 24: resnetv15_stage2_batchnorm1_fwd
# Node 25: resnetv15_stage2__plus0
# Node 26: resnetv15_stage2_activation0
# Node 27: resnetv15_stage2_conv3_fwd
# Node 28: resnetv15_stage2_batchnorm3_fwd
# Node 29: resnetv15_stage2_relu1_fwd
# Node 30: resnetv15_stage2_conv4_fwd
# Node 31: resnetv15_stage2_batchnorm4_fwd
# Node 32: resnetv15_stage2__plus1
# Node 33: resnetv15_stage2_activation1
# Node 34: resnetv15_stage3_conv2_fwd
# Node 35: resnetv15_stage3_batchnorm2_fwd
# Node 36: resnetv15_stage3_conv0_fwd
# Node 37: resnetv15_stage3_batchnorm0_fwd
# Node 38: resnetv15_stage3_relu0_fwd
# Node 39: resnetv15_stage3_conv1_fwd
# Node 40: resnetv15_stage3_batchnorm1_fwd
# Node 41: resnetv15_stage3__plus0
# Node 42: resnetv15_stage3_activation0
# Node 43: resnetv15_stage3_conv3_fwd
# Node 44: resnetv15_stage3_batchnorm3_fwd
# Node 45: resnetv15_stage3_relu1_fwd
# Node 46: resnetv15_stage3_conv4_fwd
# Node 47: resnetv15_stage3_batchnorm4_fwd
# Node 48: resnetv15_stage3__plus1
# Node 49: resnetv15_stage3_activation1
# Node 50: resnetv15_stage4_conv2_fwd
# Node 51: resnetv15_stage4_batchnorm2_fwd
# Node 52: resnetv15_stage4_conv0_fwd
# Node 53: resnetv15_stage4_batchnorm0_fwd
# Node 54: resnetv15_stage4_relu0_fwd
# Node 55: resnetv15_stage4_conv1_fwd
# Node 56: resnetv15_stage4_batchnorm1_fwd
# Node 57: resnetv15_stage4__plus0
# Node 58: resnetv15_stage4_activation0
# Node 59: resnetv15_stage4_conv3_fwd
# Node 60: resnetv15_stage4_batchnorm3_fwd
# Node 61: resnetv15_stage4_relu1_fwd
# Node 62: resnetv15_stage4_conv4_fwd
# Node 63: resnetv15_stage4_batchnorm4_fwd
# Node 64: resnetv15_stage4__plus1
# Node 65: resnetv15_stage4_activation1
# Node 66: resnetv15_pool1_fwd
# Node 67: flatten_170
# Node 68: resnetv15_dense0_fwd

# %%
extract_range_layers("ONNX_models/resnet18-v1-7.onnx", "ONNX_patterns/Resnet.onnx", 3, 9)

# %%
extract_range_layers("ONNX_models/resnet18-v1-7.onnx", "ONNX_patterns/Resnet2.onnx", 17, 25)

# %%
extract_range_layers("ONNX_models/densenet-3.onnx", "ONNX_patterns/Denseblock.onnx", 5, 49)

# %%
model_indices("ONNX_models\shufflenet-v2-12.onnx")
# Out:
# Node 0: Conv_0
# Node 1: BatchNormalization_1
# Node 2: Relu_2
# Node 3: MaxPool_3
# Node 4: Conv_4
# Node 5: BatchNormalization_5
# Node 6: Conv_6
# Node 7: BatchNormalization_7
# Node 8: Relu_8
# Node 9: Conv_9
# Node 10: BatchNormalization_10
# Node 11: Relu_11
# Node 12: Conv_12
# Node 13: BatchNormalization_13
# Node 14: Conv_14
# Node 15: BatchNormalization_15
# Node 16: Relu_16
# Node 17: Concat_17
# Node 18: Constant_18
# Node 19: Reshape_19
# Node 20: Transpose_20
# Node 21: Constant_21
# Node 22: Reshape_22
# Node 23: Split_23
# Node 24: Conv_24
# Node 25: BatchNormalization_25
# Node 26: Relu_26
# Node 27: Conv_27
# Node 28: BatchNormalization_28
# Node 29: Conv_29
# Node 30: BatchNormalization_30
# Node 31: Relu_31
# Node 32: Concat_32
# Node 33: Constant_33
# Node 34: Reshape_34
# Node 35: Transpose_35
# Node 36: Constant_36
# Node 37: Reshape_37
# Node 38: Split_38
# Node 39: Conv_39
# Node 40: BatchNormalization_40
# Node 41: Relu_41
# Node 42: Conv_42
# Node 43: BatchNormalization_43
# Node 44: Conv_44
# Node 45: BatchNormalization_45
# Node 46: Relu_46
# Node 47: Concat_47
# Node 48: Constant_48
# Node 49: Reshape_49
# Node 50: Transpose_50
# Node 51: Constant_51
# Node 52: Reshape_52
# Node 53: Split_53
# Node 54: Conv_54
# Node 55: BatchNormalization_55
# Node 56: Relu_56
# Node 57: Conv_57
# Node 58: BatchNormalization_58
# Node 59: Conv_59
# Node 60: BatchNormalization_60
# Node 61: Relu_61
# Node 62: Concat_62
# Node 63: Constant_63
# Node 64: Reshape_64
# Node 65: Transpose_65
# Node 66: Constant_66
# Node 67: Reshape_67
# Node 68: Conv_68
# Node 69: BatchNormalization_69
# Node 70: Conv_70
# Node 71: BatchNormalization_71
# Node 72: Relu_72
# Node 73: Conv_73
# Node 74: BatchNormalization_74
# Node 75: Relu_75
# Node 76: Conv_76
# Node 77: BatchNormalization_77
# Node 78: Conv_78
# Node 79: BatchNormalization_79
# Node 80: Relu_80
# Node 81: Concat_81
# Node 82: Constant_82
# Node 83: Reshape_83
# Node 84: Transpose_84
# Node 85: Constant_85
# Node 86: Reshape_86
# Node 87: Split_87
# Node 88: Conv_88
# Node 89: BatchNormalization_89
# Node 90: Relu_90
# Node 91: Conv_91
# Node 92: BatchNormalization_92
# Node 93: Conv_93
# Node 94: BatchNormalization_94
# Node 95: Relu_95
# Node 96: Concat_96
# Node 97: Constant_97
# Node 98: Reshape_98
# Node 99: Transpose_99
# Node 100: Constant_100
# Node 101: Reshape_101
# Node 102: Split_102
# Node 103: Conv_103
# Node 104: BatchNormalization_104
# Node 105: Relu_105
# Node 106: Conv_106
# Node 107: BatchNormalization_107
# Node 108: Conv_108
# Node 109: BatchNormalization_109
# Node 110: Relu_110
# Node 111: Concat_111
# Node 112: Constant_112
# Node 113: Reshape_113
# Node 114: Transpose_114
# Node 115: Constant_115
# Node 116: Reshape_116
# Node 117: Split_117
# Node 118: Conv_118
# Node 119: BatchNormalization_119
# Node 120: Relu_120
# Node 121: Conv_121
# Node 122: BatchNormalization_122
# Node 123: Conv_123
# Node 124: BatchNormalization_124
# Node 125: Relu_125
# Node 126: Concat_126
# Node 127: Constant_127
# Node 128: Reshape_128
# Node 129: Transpose_129
# Node 130: Constant_130
# Node 131: Reshape_131
# Node 132: Split_132
# Node 133: Conv_133
# Node 134: BatchNormalization_134
# Node 135: Relu_135
# Node 136: Conv_136
# Node 137: BatchNormalization_137
# Node 138: Conv_138
# Node 139: BatchNormalization_139
# Node 140: Relu_140
# Node 141: Concat_141
# Node 142: Constant_142
# Node 143: Reshape_143
# Node 144: Transpose_144
# Node 145: Constant_145
# Node 146: Reshape_146
# Node 147: Split_147
# Node 148: Conv_148
# Node 149: BatchNormalization_149
# Node 150: Relu_150
# Node 151: Conv_151
# Node 152: BatchNormalization_152
# Node 153: Conv_153
# Node 154: BatchNormalization_154
# Node 155: Relu_155
# Node 156: Concat_156
# Node 157: Constant_157
# Node 158: Reshape_158
# Node 159: Transpose_159
# Node 160: Constant_160
# Node 161: Reshape_161
# Node 162: Split_162
# Node 163: Conv_163
# Node 164: BatchNormalization_164
# Node 165: Relu_165
# Node 166: Conv_166
# Node 167: BatchNormalization_167
# Node 168: Conv_168
# Node 169: BatchNormalization_169
# Node 170: Relu_170
# Node 171: Concat_171
# Node 172: Constant_172
# Node 173: Reshape_173
# Node 174: Transpose_174
# Node 175: Constant_175
# Node 176: Reshape_176
# Node 177: Split_177
# Node 178: Conv_178
# Node 179: BatchNormalization_179
# Node 180: Relu_180
# Node 181: Conv_181
# Node 182: BatchNormalization_182
# Node 183: Conv_183
# Node 184: BatchNormalization_184
# Node 185: Relu_185
# Node 186: Concat_186
# Node 187: Constant_187
# Node 188: Reshape_188
# Node 189: Transpose_189
# Node 190: Constant_190
# Node 191: Reshape_191
# Node 192: Conv_192
# Node 193: BatchNormalization_193
# Node 194: Conv_194
# Node 195: BatchNormalization_195
# Node 196: Relu_196
# Node 197: Conv_197
# Node 198: BatchNormalization_198
# Node 199: Relu_199
# Node 200: Conv_200
# Node 201: BatchNormalization_201
# Node 202: Conv_202
# Node 203: BatchNormalization_203
# Node 204: Relu_204
# Node 205: Concat_205
# Node 206: Constant_206
# Node 207: Reshape_207
# Node 208: Transpose_208
# Node 209: Constant_209
# Node 210: Reshape_210
# Node 211: Split_211
# Node 212: Conv_212
# Node 213: BatchNormalization_213
# Node 214: Relu_214
# Node 215: Conv_215
# Node 216: BatchNormalization_216
# Node 217: Conv_217
# Node 218: BatchNormalization_218
# Node 219: Relu_219
# Node 220: Concat_220
# Node 221: Constant_221
# Node 222: Reshape_222
# Node 223: Transpose_223
# Node 224: Constant_224
# Node 225: Reshape_225
# Node 226: Split_226
# Node 227: Conv_227
# Node 228: BatchNormalization_228
# Node 229: Relu_229
# Node 230: Conv_230
# Node 231: BatchNormalization_231
# Node 232: Conv_232
# Node 233: BatchNormalization_233
# Node 234: Relu_234
# Node 235: Concat_235
# Node 236: Constant_236
# Node 237: Reshape_237
# Node 238: Transpose_238
# Node 239: Constant_239
# Node 240: Reshape_240
# Node 241: Split_241
# Node 242: Conv_242
# Node 243: BatchNormalization_243
# Node 244: Relu_244
# Node 245: Conv_245
# Node 246: BatchNormalization_246
# Node 247: Conv_247
# Node 248: BatchNormalization_248
# Node 249: Relu_249
# Node 250: Concat_250
# Node 251: Constant_251
# Node 252: Reshape_252
# Node 253: Transpose_253
# Node 254: Constant_254
# Node 255: Reshape_255
# Node 256: Conv_256
# Node 257: BatchNormalization_257
# Node 258: Relu_258
# Node 259: ReduceMean_259
# Node 260: Gemm_260

# %%
extract_range_layers("ONNX_models\shufflenet-v2-12.onnx", "ONNX_patterns/Shufflenet-1.onnx", 19, 38)
extract_range_layers("ONNX_models\shufflenet-v2-12.onnx", "ONNX_patterns/Shufflenet-2.onnx", 23, 38)
extract_range_layers("ONNX_models\shufflenet-v2-12.onnx", "ONNX_patterns/Shufflenet-3.onnx", 23, 32)

# %%
extract_range_layers("ONNX_models\inception-v2-3.onnx", "ONNX_patterns/Inception.onnx", 16, 53)

# %%
extract_range_layers("ONNX_models\googlenet-12-int8.onnx", "ONNX_patterns/Inception-g.onnx", 10, 24)

# %%
extract_range_layers("ONNX_models\squeezenet1.1-7.onnx", "ONNX_patterns/squeezeNet-1.onnx", 4, 10)
extract_range_layers("ONNX_models\squeezenet1.1-7.onnx", "ONNX_patterns/squeezeNet-2.onnx", 10, 18)

# %%
extract_range_layers("ONNX_models\mobilenetv2-10.onnx", "ONNX_patterns/squeeze_and_excite-1.onnx", 9, 16)
extract_range_layers("ONNX_models\mobilenetv2-10.onnx", "ONNX_patterns/squeeze_and_excite-2.onnx", 20, 35)

# %%
extract_range_layers("ONNX_models\efficientnet-lite4-11.onnx", "ONNX_patterns/squeeze_and_excite-3.onnx", 11, 31)
extract_range_layers("ONNX_models\efficientnet-lite4-11.onnx", "ONNX_patterns/squeeze_and_excite-4.onnx", 11, 18)

# %%
extract_range_layers("ONNX_models\espnetv2_s_2.0_imsize_224x224_imagenet.onnx", "ONNX_patterns/ESPNet-1.onnx", 0, 30)
extract_range_layers("ONNX_models\espnetv2_s_2.0_imsize_224x224_imagenet.onnx", "ONNX_patterns/ESPNet-2.onnx", 61, 78)

# %%
extract_range_layers("ONNX_models/resnext.onnx", "ONNX_patterns/bottleneck_residual.onnx", 2, 10)
extract_range_layers("ONNX_models/resnext.onnx", "ONNX_patterns/bottleneck_residual1.onnx", 10, 17)

# %%
extract_range_layers("ONNX_models/resnext.onnx", "ONNX_patterns/art_block1.onnx", 10, 45)
extract_range_layers("ONNX_models/resnext.onnx", "ONNX_patterns/art_block2.onnx", 10, 54)

# %%
extract_range_layers("ONNX_models/resnext.onnx", "ONNX_patterns/art_block3.onnx", 11, 54)

# %%
extract_range_layers("ONNX_models/resnest.onnx", "ONNX_patterns/resnest1.onnx",8,64 )

# %%
import pandas as pd
import pickle

# Read the Excel sheet into a pandas DataFrame
excel_file = 'data.xlsx'  # Replace with your Excel file path
df = pd.read_excel(excel_file)

# Convert the DataFrame to a pickle file
pickle_file = 'data.pkl'  # Replace with your desired pickle file path
with open(pickle_file, 'wb') as f:
    pickle.dump(df, f)

print('Pickle dataset created successfully.')
# Out:
# Pickle dataset created successfully.

# %%
import pickle

with open('data.pkl', 'rb') as file:
    data = pickle.load(file)

# Process or examine the data
print(data)

file.close()
# Out:
#     Unnamed: 0                 Unnamed: 1                  Unnamed: 2  \
# 0          NaN                        NaN                         NaN
# 1          NaN               Pattern name  Pattern type (Micro/Macro)
# 2          1.0                Resnet.onnx                       Micro
# 3          2.0               Resnet2.onnx                       Micro
# 4          3.0            Denseblock.onnx                       Macro
# 5          4.0              ESPNet-1.onnx                       Macro
# 6          5.0              ESPNet-2.onnx                       Macro
# 7          6.0             Inception.onnx                       Micro
# 8          7.0           Inception-g.onnx                       Micro
# 9          8.0          Shufflenet-1.onnx                       Micro
# 10         9.0          Shufflenet-2.onnx                       Micro
# 11        10.0          Shufflenet-3.onnx                       Micro
# 12        11.0  squeeze_and_excite-1.onnx                       Micro
# 13        12.0  squeeze_and_excite-2.onnx                       Micro
# 14        13.0  squeeze_and_excite-3.onnx                       Micro
# 15        14.0  squeeze_and_excite-4.onnx                       Micro
# 16        15.0          squeezeNet-1.onnx                       Micro
# 17        16.0          squeezeNet-2.onnx                       Micro
# 18        17.0   bottleneck_residual.onnx                       Micro
# 19        18.0  bottleneck_residual1.onnx                       Micro
# 20        19.0            art_block1.onnx                       Macro
# 21        20.0            art_block2.onnx                       Macro
# 22        21.0            art_block3.onnx                       Macro
# 23        22.0               Resnest.onnx                       Macro
# 24        23.0              Resnest1.onnx                       Macro
#
#                                            Unnamed: 3
# 0                                                 NaN
# 1                                            Metadata
# 2     Skip connection, Two fixed size conv layers,add
# 3     Skip connection, Two fixed size conv layers,add
# 4            Connections with every consequent layers
# 5   Point-wise convolutions,concat,depth-wise dila...
# 6   Point-wise convolutions,concat,depth-wise dila...
# 7   Combination of 1x1,3x3,5x5 convolution layers,...
# 8   Combination of 1x1,3x3,5x5 convolution layers,...
# 9               Split, concat, 3 convolutional layers
# 10              Split, concat, 3 convolutional layers
# 11              Split, concat, 3 convolutional layers
# 12  Clip, add, 3 convolutional layers, skip connec...
# 13  Clip, add, 3 convolutional layers, skip connec...
# 14  Clip, add, 3 convolutional layers, skip connec...
# 15  Clip, add, 3 convolutional layers, skip connec...
# 16                   Concat, Two parallel conv layers
# 17                   Concat, Two parallel conv layers
# 18  Skip connection, three conv layers with sequen...
# 19  Skip connection, three conv layers with sequen...
# 20  Bottleneck_residual block in parallel,Skip con...
# 21  Bottleneck_residual block in parallel,Skip con...
# 22  Bottleneck_residual block in parallel,Skip con...
# 23  2 conv layers (1x1,3x3) in parallel, split, co...
# 24  3 conv layers (1x1,3x3) in parallel, split, co...
